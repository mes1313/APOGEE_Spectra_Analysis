# %%
import astropy
from astropy.io import fits
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('Troup et al. 2016 (YES RED CLUMP) Final.csv')
df
# Out:
#     Unnamed: 0           APOGEE_ID  LOCATION_ID             FIELD  NVISITS  \
# 0            1  2M00114326+7112562         4120  120+08                 11
# 1           27  2M03072395+7944317         4205  PAL1                   10
# 2           32  2M03221892+7846028         4205  PAL1                   10
# 3           33  2M03225614+7935522         4205  PAL1                   14
# 4           35  2M03262508+8007344         4205  PAL1                   29
# 5           68  2M04411627+5855354         4121  150+08                 12
# 6           74  2M04504284+5753538         4121  150+08                 11
# 7           79  2M05224382+4300425         4145  165+04                 13
# 8          100  2M06080116+1326140         4258  195-04                 12
# 9          103  2M06142559+3313468         4149  180+08                 12
# 10         107  2M06172325+0000514         4123  210-08                 12
# ...

# %%
len(df)
# Out:
# 50

# %%
2M04123153+6738486
q

# %%
field_new = [x.strip(' ') for x in df['FIELD']]

for i in range (len(df)):
    print("https://dr17.sdss.org/sas/dr17/apogee/spectro/redux/dr17/stars/apo25m/" + field_new[i] + "/apStar-dr17-" + df['APOGEE_ID'][i] + ".fits")
# Out:
# https://dr17.sdss.org/sas/dr17/apogee/spectro/redux/dr17/stars/apo25m/120+08/apStar-dr17-2M00114326+7112562.fits
# https://dr17.sdss.org/sas/dr17/apogee/spectro/redux/dr17/stars/apo25m/PAL1/apStar-dr17-2M03072395+7944317.fits
# https://dr17.sdss.org/sas/dr17/apogee/spectro/redux/dr17/stars/apo25m/PAL1/apStar-dr17-2M03221892+7846028.fits
# https://dr17.sdss.org/sas/dr17/apogee/spectro/redux/dr17/stars/apo25m/PAL1/apStar-dr17-2M03225614+7935522.fits
# https://dr17.sdss.org/sas/dr17/apogee/spectro/redux/dr17/stars/apo25m/PAL1/apStar-dr17-2M03262508+8007344.fits
# https://dr17.sdss.org/sas/dr17/apogee/spectro/redux/dr17/stars/apo25m/150+08/apStar-dr17-2M04411627+5855354.fits
# https://dr17.sdss.org/sas/dr17/apogee/spectro/redux/dr17/stars/apo25m/150+08/apStar-dr17-2M04504284+5753538.fits
# https://dr17.sdss.org/sas/dr17/apogee/spectro/redux/dr17/stars/apo25m/165+04/apStar-dr17-2M05224382+4300425.fits
# ...
